# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
loading=pd.read_csv('./X_loadings_648.csv', header=None, delimiter=';')

# %%
reduced=pd.read_csv('./X_reduced_648.csv', header=None, delimiter=';')

# %%
Z = np.dot(loading, reduced.transpose())
plt.imshow(Z)
